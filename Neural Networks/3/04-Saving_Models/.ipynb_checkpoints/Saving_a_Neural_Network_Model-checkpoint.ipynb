# %% [markdown]
# # Saving and Loading a Neural Network Model

# %%
# Initial imports
import pandas as pd
from pathlib import Path

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ## Read in Data

# %%
# Set the CSV file path
file_path = Path("wine_quality.csv")

# Read the data into a DataFrame
df = pd.read_csv(file_path)

# Display sample data
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# ## Data Preprocessing

# %%
# Create the features (X) and target (y) sets
X = df.drop(columns=["quality"]).values
y = df["quality"].values

# %%
# Create training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create scaler instance
X_scaler = StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the features data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Creating the Model

# %%
# Define the model - deep neural net with two hidden layers
number_input_features = 11
hidden_nodes_layer1 = 8
hidden_nodes_layer2 = 4

# Create a sequential neural network model
nn_1 = Sequential()

# Add the first hidden layer
nn_1.add(Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Add the second hidden layer
nn_1.add(Dense(units=hidden_nodes_layer2, activation="relu"))

# Add the output layer
nn_1.add(Dense(units=1, activation="linear"))

# %%
# Compile model
nn_1.compile(loss="mean_squared_error", optimizer="adam", metrics=["mse"])

# %%
# Fit the model
deep_net_model_1 = nn_1.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 0s 1ms/step - loss: 35.0204 - mse: 35.0204
# Epoch 2/100
# 38/38 [==============================] - 0s 1ms/step - loss: 32.4616 - mse: 32.4616
# Epoch 3/100
# 38/38 [==============================] - 0s 1ms/step - loss: 30.1069 - mse: 30.1069
# Epoch 4/100
# 38/38 [==============================] - 0s 1ms/step - loss: 27.1975 - mse: 27.1975
# Epoch 5/100
# 38/38 [==============================] - 0s 1ms/step - loss: 23.7620 - mse: 23.7620
# Epoch 6/100
# 38/38 [==============================] - 0s 1ms/step - loss: 19.9915 - mse: 19.9915
# Epoch 7/100
# 38/38 [==============================] - 0s 1ms/step - loss: 16.4908 - mse: 16.4908
# Epoch 8/100
# 38/38 [==============================] - 0s 1ms/step - loss: 13.5318 - mse: 13.5318
# Epoch 9/100
# 38/38 [==============================] - 0s 1ms/step - loss: 10.8826 - mse: 10.8826
# Epoch 10/100
# 38/38 [==============================] - 0s 1ms/step - loss: 8.3411 - mse: 8.3411
# Epoch 11/100
# 38/38 [==============================] - 0s 1ms/step - loss: 6.0043 - mse: 6.0043
# Epoch 12/100
# 38/38 [==============================] - 0s 1ms/step - loss: 4.1790 - mse: 4.1790
# Epoch 13/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3.0142 - mse: 3.0142
# Epoch 14/100
# 38/38 [==============================] - 0s 1ms/step - loss: 2.3812 - mse: 2.3812
# Epoch 15/100
# 38/38 [==============================] - 0s 1ms/step - loss: 2.0844 - mse: 2.0844
# Epoch 16/100
# 38/38 [==============================] - 0s 1ms/step - loss: 1.9031 - mse: 1.9031
# Epoch 17/100
# 38/38 [==============================] - 0s 1ms/step - loss: 1.7763 - mse: 1.7763
# Epoch 18/100
# 38/38 [==============================] - 0s 1ms/step - loss: 1.6721 - mse: 1.6721
# Epoch 19/100
# 38/38 [==============================] - 0s 1ms/step - loss: 1.5735 - mse: 1.5735
# Epoch 20/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.4844 - mse: 1.4844
# Epoch 21/100
# 38/38 [==============================] - 0s 1ms/step - loss: 1.4079 - mse: 1.4079
# Epoch 22/100
# 38/38 [==============================] - 0s 1ms/step - loss: 1.3379 - mse: 1.3379
# Epoch 23/100
# 38/38 [==============================] - 0s 1ms/step - loss: 1.2700 - mse: 1.2700
# Epoch 24/100
# 38/38 [==============================] - 0s 1ms/step - loss: 1.2074 - mse: 1.2074
# Epoch 25/100
# 38/38 [==============================] - 0s 1ms/step - loss: 1.1556 - mse: 1.1556
# Epoch 26/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.1048 - mse: 1.1048
# Epoch 27/100
# 38/38 [==============================] - 0s 1ms/step - loss: 1.0594 - mse: 1.0594
# Epoch 28/100
# 38/38 [==============================] - 0s 1ms/step - loss: 1.0177 - mse: 1.0177
# Epoch 29/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.9786 - mse: 0.9786
# Epoch 30/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.9422 - mse: 0.9422
# Epoch 31/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.9084 - mse: 0.9084
# Epoch 32/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.8775 - mse: 0.8775
# Epoch 33/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.8493 - mse: 0.8493
# Epoch 34/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.8242 - mse: 0.8242
# Epoch 35/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.7992 - mse: 0.7992
# Epoch 36/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.7768 - mse: 0.7768
# Epoch 37/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.7553 - mse: 0.7553
# Epoch 38/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.7364 - mse: 0.7364
# Epoch 39/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.7185 - mse: 0.7185
# Epoch 40/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.7008 - mse: 0.7008
# Epoch 41/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.6853 - mse: 0.6853
# Epoch 42/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.6693 - mse: 0.6693
# Epoch 43/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.6573 - mse: 0.6573
# Epoch 44/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.6438 - mse: 0.6438
# Epoch 45/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.6332 - mse: 0.6332
# Epoch 46/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.6219 - mse: 0.6219
# Epoch 47/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.6114 - mse: 0.6114
# Epoch 48/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.6019 - mse: 0.6019
# Epoch 49/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.5934 - mse: 0.5934
# Epoch 50/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.5831 - mse: 0.5831
# Epoch 51/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.5770 - mse: 0.5770
# Epoch 52/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.5696 - mse: 0.5696
# Epoch 53/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.5609 - mse: 0.5609
# Epoch 54/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.5533 - mse: 0.5533
# Epoch 55/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.5496 - mse: 0.5496
# Epoch 56/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.5413 - mse: 0.5413
# Epoch 57/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.5366 - mse: 0.5366
# Epoch 58/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.5326 - mse: 0.5326
# Epoch 59/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.5259 - mse: 0.5259
# Epoch 60/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.5224 - mse: 0.5224
# Epoch 61/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.5167 - mse: 0.5167
# Epoch 62/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.5150 - mse: 0.5150
# Epoch 63/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.5112 - mse: 0.5112
# Epoch 64/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5062 - mse: 0.5062
# Epoch 65/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.5034 - mse: 0.5034
# Epoch 66/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.5004 - mse: 0.5004
# Epoch 67/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4942 - mse: 0.4942
# Epoch 68/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4920 - mse: 0.4920
# Epoch 69/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4880 - mse: 0.4880
# Epoch 70/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4843 - mse: 0.4843
# Epoch 71/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4813 - mse: 0.4813
# Epoch 72/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4779 - mse: 0.4779
# Epoch 73/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4762 - mse: 0.4762
# Epoch 74/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4737 - mse: 0.4737
# Epoch 75/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4695 - mse: 0.4695
# Epoch 76/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4677 - mse: 0.4677
# Epoch 77/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4646 - mse: 0.4646
# Epoch 78/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4624 - mse: 0.4624
# Epoch 79/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4614 - mse: 0.4614
# Epoch 80/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4596 - mse: 0.4596
# Epoch 81/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4561 - mse: 0.4561
# Epoch 82/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4551 - mse: 0.4551
# Epoch 83/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4524 - mse: 0.4524
# Epoch 84/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4512 - mse: 0.4512
# Epoch 85/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4494 - mse: 0.4494
# Epoch 86/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4472 - mse: 0.4472
# Epoch 87/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4459 - mse: 0.4459
# Epoch 88/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4438 - mse: 0.4438
# Epoch 89/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4407 - mse: 0.4407
# Epoch 90/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4389 - mse: 0.4389
# Epoch 91/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4377 - mse: 0.4377
# Epoch 92/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4355 - mse: 0.4355
# Epoch 93/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4347 - mse: 0.4347
# Epoch 94/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4326 - mse: 0.4326
# Epoch 95/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4320 - mse: 0.4320
# Epoch 96/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4294 - mse: 0.4294
# Epoch 97/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4300 - mse: 0.4300
# Epoch 98/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4277 - mse: 0.4277
# Epoch 99/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4249 - mse: 0.4249
# Epoch 100/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4298 - mse: 0.4298

# %% [markdown]
# ## Saving the Trained Model

# %%
# Set the model's file path
file_path = Path("Resources/wine_quality.h5")

# Export your model to an HDF5 file
nn_1.save(file_path)

# %% [markdown]
# ## Loading a Trained Model

# %%
# Import the required libraries
import tensorflow as tf

# %%
# Set the model's file path
file_path = Path("Resources/wine_quality.h5")

# Load the model to a new object
nn_imported = tf.keras.models.load_model(file_path)

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_imported.evaluate(X_test_scaled, y_test, verbose=2)

# Display evaluation results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 13/13 - 0s - loss: 0.4154 - mse: 0.4154 - 173ms/epoch - 13ms/step
# Loss: 0.4154045581817627, Accuracy: 0.4154045581817627
